# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
data = {
    "EA1": {5: [0.07, 0.01, 0.29, 0.34, 0.01],
             6: [0.36, 0.12, 0.38, 0.59, 0.08],
             7: [0.39, 0.16, 1.11, 0.97, 1.18],
             8: [0.60, 0.33, 1.98, 1.47, 0.98]},
    "EA2": {5: [0.07, 0.48, 0.16, 0.01, 0.17],
             6: [0.18, 0.35, 0.55, 0.31, 1.23],
             7: [1.21, 1.13, 0.70, 1.35, 0.09],
             8: [2.93, 0.67, 0.76, 2.25, 1.73]},
    "EA3": {5: [0.14, 0.70, 0.08, 0.02, 0.05],
             6: [0.08, 0.17, 0.47, 0.42, 0.67],
             7: [0.76, 0.81, 1.87, 1.51, 2.10],
             8: [1.09, 1.84, 1.10, 4.49, 1.10]}
}


ac_data = {
    "AC1": {5: [x / 1e6 for x in [9210667, 2931659, 2491066, 2441284, 2394197]],
                 6: [x / 1e6 for x in [2039924, 1941690, 1794531, 2318673, 1500229]],
                 7: [x / 1e6 for x in [267813, 305918, 257282, 262122, 274911]],
                 8: [x / 1e6 for x in [1256104, 1169166, 1226183, 1212399, 1012037]]},
    "AC2": {5: [x / 1e6 for x in [2252756, 2388879, 2460480, 2347918, 2391710]],
                 6: [x / 1e6 for x in [406248, 396401, 385725, 372977, 384702]],
                 7: [x / 1e6 for x in [421780, 536254, 683440, 1811840, 919959]],
                 8: [x / 1e6 for x in [3290962, 3308387, 3140313, 3266020, 3149778]]},
    "AC3": {5: [x / 1e6 for x in [1328430, 1241096, 1321203, 1613058, 1554128]],
                 6: [x / 1e6 for x in [448183, 385093, 372458, 388761, 357624]],
                 7: [x / 1e6 for x in [1296980, 2089115, 2085183, 651735, 752349]],
                 8: [x / 1e6 for x in [2004300, 1643686, 1502862, 1524284, 2800220]]}
}

plt.figure(figsize=(10, 6))

# Scatter plot each EA set
for label, values in data.items():
    for x, y_list in values.items():
        plt.scatter([x] * len(y_list), y_list, label=label if x == 5 else "", marker='o', alpha=0.7)

# Scatter plot each AC set with distinct 'X' markers
for label, values in ac_data.items():
    for x, y_list in values.items():
        plt.scatter([x] * len(y_list), y_list, label=label if x == 5 else "", marker='X', s=100, alpha=0.9, edgecolors='black')

plt.xlabel("Missing values")
plt.ylabel("Execution Time (ms)")
plt.title("Execution Time vs Missing values (not normalised)")
plt.xticks([5, 6, 7, 8])  # Ensure only 5,6,7,8 are shown on the x-axis
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data with EA values divided by 4.5
data = {
    "EA1": {5: [x / 4.5 for x in [0.07, 0.01, 0.29, 0.34, 0.01]],
             6: [x / 4.5 for x in [0.36, 0.12, 0.38, 0.59, 0.08]],
             7: [x / 4.5 for x in [0.39, 0.16, 1.11, 0.97, 1.18]],
             8: [x / 4.5 for x in [0.60, 0.33, 1.98, 1.47, 0.98]]},
    "EA2": {5: [x / 4.5 for x in [0.07, 0.48, 0.16, 0.01, 0.17]],
             6: [x / 4.5 for x in [0.18, 0.35, 0.55, 0.31, 1.23]],
             7: [x / 4.5 for x in [1.21, 1.13, 0.70, 1.35, 0.09]],
             8: [x / 4.5 for x in [2.93, 0.67, 0.76, 2.25, 1.73]]},
    "EA3": {5: [x / 4.5 for x in [0.14, 0.70, 0.08, 0.02, 0.05]],
             6: [x / 4.5 for x in [0.08, 0.17, 0.47, 0.42, 0.67]],
             7: [x / 4.5 for x in [0.76, 0.81, 1.87, 1.51, 2.10]],
             8: [x / 4.5 for x in [1.09, 1.84, 1.10, 4.49, 1.10]]}
}


ac_data = {
    "AC1": {5: [x / 1e6 for x in [9210667, 2931659, 2491066, 2441284, 2394197]],
                 6: [x / 1e6 for x in [2039924, 1941690, 1794531, 2318673, 1500229]],
                 7: [x / 1e6 for x in [267813, 305918, 257282, 262122, 274911]],
                 8: [x / 1e6 for x in [1256104, 1169166, 1226183, 1212399, 1012037]]},
    "AC2": {5: [x / 1e6 for x in [2252756, 2388879, 2460480, 2347918, 2391710]],
                 6: [x / 1e6 for x in [406248, 396401, 385725, 372977, 384702]],
                 7: [x / 1e6 for x in [421780, 536254, 683440, 1811840, 919959]],
                 8: [x / 1e6 for x in [3290962, 3308387, 3140313, 3266020, 3149778]]},
    "AC3": {5: [x / 1e6 for x in [1328430, 1241096, 1321203, 1613058, 1554128]],
                 6: [x / 1e6 for x in [448183, 385093, 372458, 388761, 357624]],
                 7: [x / 1e6 for x in [1296980, 2089115, 2085183, 651735, 752349]],
                 8: [x / 1e6 for x in [2004300, 1643686, 1502862, 1524284, 2800220]]}
}

plt.figure(figsize=(10, 6))

# Scatter plot each EA set
for label, values in data.items():
    for x, y_list in values.items():
        plt.scatter([x] * len(y_list), y_list, label=label if x == 5 else "", marker='o', alpha=0.7)

# Scatter plot each sudoku set with distinct 'X' markers
for label, values in ac_data.items():
    for x, y_list in values.items():
        plt.scatter([x] * len(y_list), y_list, label=label if x == 5 else "", marker='X', s=100, alpha=0.9, edgecolors='black')

plt.xlabel("Missing values")
plt.ylabel("Execution Time (ms)")
plt.title("Execution Time vs Missing values (normalised)")
plt.xticks([5, 6, 7, 8])  # Ensure only 5,6,7,8 are shown on the x-axis
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np

data = {
    (1, 5): [(5, 0.07164233299954503), (0, 0.012269452000509773), (23, 0.28523579000011523), (27, 0.3357235359999322), (0, 0.012168716000815039)],
    (1, 6): [(30, 0.35762812300072255), (11, 0.14100757500000327), (31, 0.37967656000000716), (49, 0.5883466810000755), (6, 0.08232539199980238)],
    (1, 7): [(33, 0.39417133099959756), (12, 0.15092822299993713), (93, 1.108279663999383), (82, 0.9699797279999984), (99, 1.1771173469996938)],
    (1, 8): [(49, 0.5969108070003131), (27, 0.32722608800031594), (164, 1.9813726949996635), (124, 1.472002268000324), (82, 0.9838662519996433)],
    (2, 5): [(5, 0.07037048500023957), (40, 0.4775251159999243), (13, 0.16130446399984066), (0, 0.011937709000449104), (13, 0.1656597539995346)],
    (2, 6): [(13, 0.17882389800070086), (29, 0.34894606699981523), (44, 0.5459546450001653), (26, 0.3139091560005909), (105, 1.2336843940001927)],
    (2, 7): [(102, 1.20734406199972), (94, 1.1334934739998062), (59, 0.7045472540003175), (112, 1.349732665999909), (6, 0.08725668599981873)],
    (2, 8): [(242, 2.932644120999612), (55, 0.6676744160004091), (62, 0.7585860250001133), (189, 2.253342882000652), (143, 1.7292727059993922)],
    (3, 5): [(11, 0.13854478800021752), (59, 0.6960521000000881), (6, 0.08470273499915493), (1, 0.023844522000217694), (3, 0.04714947399952507)],
    (3, 6): [(6, 0.08259854300013103), (14, 0.1732845329997872), (39, 0.4721593589993063), (35, 0.4179156090003744), (57, 0.6736139120002917)],
    (3, 7): [(63, 0.7555979460003073), (67, 0.8122815420001643), (159, 1.8732381790005093), (127, 1.5123174919999656), (177, 2.0955965120001565)],
    (3, 8): [(91, 1.0873977210003432), (156, 1.842041486999733), (91, 1.0960633620006774), (376, 4.489579226999922), (91, 1.0969508409998525)]
}

# Extract unique hyper-parameter settings (n values)
n_values = sorted(set(key[1] for key in data.keys()))

# Define colors and markers for Sudoku versions
sudoku_styles = {
    1: ('r', 'o'),  # Red circles
    2: ('g', 's'),  # Green squares
    3: ('b', '^')   # Blue triangles
}

plt.figure(figsize=(10, 6))

for n in n_values:
    for sudoku in [1, 2, 3]:
        if (sudoku, n) in data:
            iterations = [entry[0] for entry in data[(sudoku, n)]]
            color, marker = sudoku_styles[sudoku]
            plt.scatter([n] * len(iterations), iterations, color=color, marker=marker, label=f'Sudoku {sudoku}' if n == n_values[0] else "")

plt.xlabel("Missing values")
plt.ylabel("Generations")
plt.title("EA generations vs. missing values")
plt.xticks([5, 6, 7, 8])  # Ensure only 5,6,7,8 are shown on the x-axis
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
